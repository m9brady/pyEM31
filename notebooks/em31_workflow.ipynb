# %% [markdown]
# # pyEM31 Example Workflow
# Based on data collected during the 2016 Eureka Experiment

# %%
# %load_ext autoreload
# %autoreload 2

# add local git repo directory to import path
import sys

sys.path.append("..")
import em31

# %%
file_path = "../data/em31/041118A.R31"
df_em31 = em31.read_data(file_path, gps_tol=5)
df_em31 = em31.thickness(df_em31, 0.15)

# %%
df_em31.head(5)
# Out:
#    l_num  time_ms     flags  range2  range3  c_factor  appcond       inph  \
# 0     17   101539  10000110       1       1     -0.25   140.00  42.400002
# 1     27   102530  10000110       1       1     -0.25   141.00  44.650002
# 2     37   103521  10000110       1       1     -0.25   142.00  47.799999
# 3     47   104512  10000110       1       1     -0.25   141.25  44.900002
# 4     57   105503  10000110       1       1     -0.25   141.00  43.400002
#
#    time_relative                 time_ds        lat        lon  \
# 0           2926 2017-04-11 18:15:48.197  83.442198 -64.415393
# 1           3917 2017-04-11 18:15:49.188  83.442199 -64.415383
# 2           4908 2017-04-11 18:15:50.179  83.442200 -64.415368
# 3           5899 2017-04-11 18:15:51.170  83.442200 -64.415366
# 4           6890 2017-04-11 18:15:52.161  83.442200 -64.415362
#
#          time_gps                time_sys      ttem
# 0  18:15:52+00:00 2017-04-11 18:15:47.942  2.271824
# 1  18:15:53+00:00 2017-04-11 18:15:48.942  2.263814
# 2  18:15:54+00:00 2017-04-11 18:15:49.942  2.255867
# 3  18:15:55+00:00 2017-04-11 18:15:50.942  2.261822
# 4  18:15:56+00:00 2017-04-11 18:15:51.943  2.263814

# %%
df_em31.plot(x="time_ms", y="ttem");
